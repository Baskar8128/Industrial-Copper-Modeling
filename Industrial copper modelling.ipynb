# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Copper_Set.csv')
data=pd.DataFrame(df)
data
# Out:
#                                           id   item_date quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262
# ...                                      ...         ...           ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0   102.4824216
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0   208.0864686
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0   4.235593568
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8  20200702.0         -2000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC  20200702.0   406.6865384
#
#           customer  country status item type  application  thickness   width  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             181671 non-null  object
#  1   item_date      181672 non-null  float64
#  2   quantity tons  181673 non-null  object
#  3   customer       181672 non-null  float64
#  4   country        181645 non-null  float64
#  5   status         181671 non-null  object
#  6   item type      181673 non-null  object
#  7   application    181649 non-null  float64
#  8   thickness      181672 non-null  float64
#  9   width          181673 non-null  float64
#  10  material_ref   103754 non-null  object
#  11  product_ref    181673 non-null  int64
#  12  delivery date  181672 non-null  float64
#  13  selling_price  181672 non-null  float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 19.4+ MB

# %%
data.describe()
# Out:
#           item_date      customer        country    application  \
# count  1.816720e+05  1.816720e+05  181645.000000  181649.000000
# mean   2.020459e+07  3.051221e+07      44.893022      25.615809
# std    4.551119e+03  2.433382e+07      24.404214      17.754175
# min    1.995000e+07  1.245800e+04      25.000000       2.000000
# 25%    2.020093e+07  3.019688e+07      26.000000      10.000000
# 50%    2.020113e+07  3.020524e+07      30.000000      15.000000
# 75%    2.021020e+07  3.028042e+07      78.000000      41.000000
# max    2.021040e+07  2.147484e+09     113.000000      99.000000
#
#            thickness          width   product_ref  delivery date  \
# count  181672.000000  181673.000000  1.816730e+05   1.816720e+05
# mean        2.564827    1295.286724  4.739679e+08   2.020738e+07
# std         6.572321     261.631754  7.175101e+08   2.411059e+04
# min         0.180000       1.000000  6.117280e+05   2.019040e+07
# ...

# %%
# heatmap for missing values
sns.heatmap(data.isnull(),cbar = False)
plt.title('Heatmap of missing data', fontsize = 15)
plt.xlabel('Variable', fontsize = 15)
plt.ylabel('material_ref', fontsize = 15)
plt.show()

# %%
#replacing missing values with most common value
data['material_ref'] = data['material_ref'].fillna(data['material_ref'].mode()[0])

# %%
#converting inappropriate values to null value
data.loc[data['material_ref'].str.startswith('0000'), 'material_ref']=None

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# id               0
# item_date        0
# quantity tons    0
# customer         0
# country          0
# status           0
# item type        0
# application      0
# thickness        0
# width            0
# material_ref     0
# product_ref      0
# delivery date    0
# selling_price    0
# dtype: int64

# %%
data.shape
# Out:
# (158910, 14)

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
#using isolation forest method to remove outliers
from sklearn.ensemble import IsolationForest
col_name = 'selling_price'
data1 = IsolationForest(n_estimators=100, contamination=0.01)
data1.fit(data[[col_name]])
out_labels = data1.predict(data[[col_name]])
df1 = data[out_labels==1]

# %%
#histogram for data visualization
df1.hist(bins=10,figsize=(15,10))
plt.show()

# %%
corr = df1.corr()
corr
# Out:
#                item_date  customer   country  application  thickness  \
# item_date       1.000000  0.001611 -0.014807    -0.002588   0.003567
# customer        0.001611  1.000000  0.086979     0.007903   0.084743
# country        -0.014807  0.086979  1.000000    -0.014792  -0.034581
# application    -0.002588  0.007903 -0.014792     1.000000  -0.124860
# thickness       0.003567  0.084743 -0.034581    -0.124860   1.000000
# width           0.013272  0.045625  0.044514    -0.188132   0.366269
# product_ref     0.043576 -0.026943 -0.148867    -0.146530   0.054189
# delivery date   0.104552  0.003170 -0.013952    -0.010259   0.002611
# selling_price   0.512830  0.001510 -0.022612     0.129242  -0.278199
#
#                   width  product_ref  delivery date  selling_price
# item_date      0.013272     0.043576       0.104552       0.512830
# customer       0.045625    -0.026943       0.003170       0.001510
# country        0.044514    -0.148867      -0.013952      -0.022612
# ...

# %%
fig,ax=plt.subplots(figsize=(15,10))
sns.heatmap(df1.corr(),annot=True,ax=ax)
# Out:
# <Axes: >
